# %% [markdown]
# # 04 Results Analysis
#
# Review the final backtest metrics, equity curve, drawdowns, and strategy-level contributions.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

project_root = Path('..').resolve()
metrics = pd.read_csv(project_root / 'outputs' / 'reports' / 'performance_metrics.csv', index_col=0)
daily_results = pd.read_csv(project_root / 'outputs' / 'reports' / 'daily_results.csv', index_col=0, parse_dates=True)
strategy_weights = pd.read_csv(project_root / 'outputs' / 'reports' / 'strategy_weights.csv', index_col=0, parse_dates=True)

metrics

# %%
daily_results[['equity_curve', 'drawdown']].plot(subplots=True, figsize=(12, 8), title='Backtest Diagnostics')
plt.show()

# %%
strategy_weights.tail()
