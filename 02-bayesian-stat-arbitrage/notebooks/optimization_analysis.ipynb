# %% [markdown]
# # Optimization Analysis
#
# Inspect Optuna trials, best parameters, and out-of-sample performance reports.

# %%
from pathlib import Path
import json
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
trials = pd.read_csv(PROJECT_ROOT / 'results' / 'optimization_logs' / 'optuna_trials.csv')
trials.sort_values('value', ascending=False).head(10)

# %%
with open(PROJECT_ROOT / 'results' / 'optimization_logs' / 'best_params.json', 'r', encoding='utf-8') as file:
    best_params = json.load(file)
best_params

# %%
with open(PROJECT_ROOT / 'results' / 'performance_reports' / 'out_of_sample_performance.json', 'r', encoding='utf-8') as file:
    report = json.load(file)
report
