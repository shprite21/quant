# %% [markdown]
# # 02 Feature Engineering
#
# Build the technical feature matrix used by the regime model and signal model.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

SRC_PATH = PROJECT_ROOT / "src"
if str(SRC_PATH) not in sys.path:
    sys.path.append(str(SRC_PATH))

from data_loader import load_ohlcv_csv
from features import build_technical_features
from utils import project_path

# %%
prices = load_ohlcv_csv(project_path("data", "raw", "SPY.csv"))
feature_frame = build_technical_features(prices)

feature_frame.to_csv(project_path("data", "processed", "SPY_features.csv"))
feature_frame.tail()
