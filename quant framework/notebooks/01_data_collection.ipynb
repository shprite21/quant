# %% [markdown]
# # 01 Data Collection
#
# Use this notebook to collect or import daily OHLCV data for equities, ETFs, indices, or continuous futures.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

SRC_PATH = PROJECT_ROOT / "src"
if str(SRC_PATH) not in sys.path:
    sys.path.append(str(SRC_PATH))

from data_loader import download_yfinance
from utils import project_path

# %%
symbol = "SPY"
start = "2015-01-01"
end = None

frame = download_yfinance(symbol=symbol, start=start, end=end)
output_path = project_path("data", "raw", f"{symbol}.csv")
frame.to_csv(output_path)
frame.tail()
